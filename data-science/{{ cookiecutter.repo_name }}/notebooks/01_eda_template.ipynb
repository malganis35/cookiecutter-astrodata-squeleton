# %% [markdown]
# # 📓 Exploratory Data Analysis Template
#
# Project: **{{ cookiecutter.project_name }}**

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
from loguru import logger

from {{ cookiecutter.package_name }}.core.utils import DATA_DIR, RAW_DATA_DIR, PROCESSED_DATA_DIR

# %% [markdown]
# ## 1. Load Data

# %% [markdown]
# ## 2. Basic Stats

# %% [markdown]
# ## 3. Visualizations
